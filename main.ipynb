# %% [markdown]
# <a href="https://colab.research.google.com/github/mandib96/case-analytics-engineer-2026/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando lib e autenticaçao com cloud
import requests
import pandas as pd

from google.colab import auth
from google.cloud import bigquery

project_id = "case-boticario-485101"

auth.authenticate_user()

client = bigquery.Client(project=project_id)
